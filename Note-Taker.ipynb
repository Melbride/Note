# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('algo_ds_info.csv')

# %%
df
# Out:
#     problem_id     problem_type                      problem_name difficulty  \
# 0            0       algorithms             day-of-the-programmer       Easy
# 1            1       algorithms                   time-conversion       Easy
# 2            2       algorithms                     sock-merchant       Easy
# 3            3       algorithms                      utopian-tree       Easy
# 4            4       algorithms                 append-and-delete       Easy
# 5            5       algorithms                     taum-and-bday       Easy
# 6            6       algorithms                      service-lane       Easy
# 7            7       algorithms              absolute-permutation     Medium
# 8            8       algorithms                    insertionsort1       Easy
# 9            9       algorithms                          pangrams       Easy
# 10          10       algorithms                   closest-numbers       Easy
# ...

# %%
df.head()
# Out:
#    problem_id problem_type           problem_name difficulty skills  max_score
# 0           0   algorithms  day-of-the-programmer       Easy  Basic         15
# 1           1   algorithms        time-conversion       Easy  Basic         15
# 2           2   algorithms          sock-merchant       Easy  Basic         10
# 3           3   algorithms           utopian-tree       Easy  Basic         20
# 4           4   algorithms      append-and-delete       Easy  Basic         20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   problem_id    57 non-null     int64
#  1   problem_type  57 non-null     object
#  2   problem_name  57 non-null     object
#  3   difficulty    57 non-null     object
#  4   skills        57 non-null     object
#  5   max_score     57 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 2.8+ KB

# %%
df.describe()
# Out:
#        problem_id   max_score
# count   57.000000   57.000000
# mean    28.000000   56.052632
# std     16.598193   34.817597
# min      0.000000    5.000000
# 25%     14.000000   30.000000
# 50%     28.000000   50.000000
# 75%     42.000000   80.000000
# max     56.000000  150.000000

# %%
df.describe(include='all')
# Out:
#         problem_id problem_type           problem_name difficulty skills  \
# count    57.000000           57                     57         57     57
# unique         NaN            2                     57          5      4
# top            NaN   algorithms  day-of-the-programmer     Medium   Null
# freq           NaN           45                      1         19     31
# mean     28.000000          NaN                    NaN        NaN    NaN
# std      16.598193          NaN                    NaN        NaN    NaN
# min       0.000000          NaN                    NaN        NaN    NaN
# 25%      14.000000          NaN                    NaN        NaN    NaN
# 50%      28.000000          NaN                    NaN        NaN    NaN
# 75%      42.000000          NaN                    NaN        NaN    NaN
# max      56.000000          NaN                    NaN        NaN    NaN
#
#          max_score
# count    57.000000
# unique         NaN
# top            NaN
# ...

# %%
df.nunique()
# Out:
# problem_id      57
# problem_type     2
# problem_name    57
# difficulty       5
# skills           4
# max_score       18
# dtype: int64

# %%
df2 = pd.read_csv('algo_ds_leaderboard.csv', sep=';')

# %%
df2
# Out:
#        problem_id     problem_type     pl            country   score  count
# 0               0       algorithms      c              India   15.00   2100
# 1               0       algorithms      c            Germany   15.00      6
# 2               0       algorithms      c  Republic of Korea   15.00      8
# 3               0       algorithms      c     United Kingdom   15.00      5
# 4               0       algorithms      c          Indonesia   15.00     20
# ...           ...              ...    ...                ...     ...    ...
# 51297          56  data structures  cpp20               Null  150.00      1
# 51298          56  data structures  cpp20              India   81.80      1
# 51299          56  data structures  pypy3      United States  122.75      1
# 51300          56  data structures  pypy3              India   95.44      1
# 51301          56  data structures  pypy3              India   81.80      1
#
# [51302 rows x 6 columns]

# %%
df2.head()
# Out:
#    problem_id problem_type pl            country  score  count
# 0           0   algorithms  c              India   15.0   2100
# 1           0   algorithms  c            Germany   15.0      6
# 2           0   algorithms  c  Republic of Korea   15.0      8
# 3           0   algorithms  c     United Kingdom   15.0      5
# 4           0   algorithms  c          Indonesia   15.0     20

# %%
df2.tail()
# Out:
#        problem_id     problem_type     pl        country   score  count
# 51297          56  data structures  cpp20           Null  150.00      1
# 51298          56  data structures  cpp20          India   81.80      1
# 51299          56  data structures  pypy3  United States  122.75      1
# 51300          56  data structures  pypy3          India   95.44      1
# 51301          56  data structures  pypy3          India   81.80      1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51302 entries, 0 to 51301
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   problem_id    51302 non-null  int64
#  1   problem_type  51302 non-null  object
#  2   pl            51302 non-null  object
#  3   country       51301 non-null  object
#  4   score         51302 non-null  float64
#  5   count         51302 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
df2.describe()
# Out:
#          problem_id         score         count
# count  51302.000000  51302.000000  51302.000000
# mean      19.641866     25.249657     10.096487
# std       17.963807     24.042509    117.191400
# min        0.000000      0.000000      1.000000
# 25%        4.000000     10.000000      1.000000
# 50%       13.000000     20.000000      1.000000
# 75%       37.000000     35.000000      3.000000
# max       56.000000    150.000000   8795.000000

# %%
df2.describe(include='all')
# Out:
#           problem_id problem_type     pl        country         score  \
# count   51302.000000        51302  51302          51301  51302.000000
# unique           NaN            2     47            290           NaN
# top              NaN   algorithms    cpp  United States           NaN
# freq             NaN        41793   4896           3419           NaN
# mean       19.641866          NaN    NaN            NaN     25.249657
# std        17.963807          NaN    NaN            NaN     24.042509
# min         0.000000          NaN    NaN            NaN      0.000000
# 25%         4.000000          NaN    NaN            NaN     10.000000
# 50%        13.000000          NaN    NaN            NaN     20.000000
# 75%        37.000000          NaN    NaN            NaN     35.000000
# max        56.000000          NaN    NaN            NaN    150.000000
#
#                count
# count   51302.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
merged_df = pd.merge(df2, df, on=['problem_id', 'problem_type'], how='left')

# %%
merged_df
# Out:
#        problem_id     problem_type     pl            country   score  count  \
# 0               0       algorithms      c              India   15.00   2100
# 1               0       algorithms      c            Germany   15.00      6
# 2               0       algorithms      c  Republic of Korea   15.00      8
# 3               0       algorithms      c     United Kingdom   15.00      5
# 4               0       algorithms      c          Indonesia   15.00     20
# ...           ...              ...    ...                ...     ...    ...
# 51297          56  data structures  cpp20               Null  150.00      1
# 51298          56  data structures  cpp20              India   81.80      1
# 51299          56  data structures  pypy3      United States  122.75      1
# 51300          56  data structures  pypy3              India   95.44      1
# 51301          56  data structures  pypy3              India   81.80      1
#
# ...

# %%
merged_df.head()
# Out:
#    problem_id problem_type pl            country  score  count  \
# 0           0   algorithms  c              India   15.0   2100
# 1           0   algorithms  c            Germany   15.0      6
# 2           0   algorithms  c  Republic of Korea   15.0      8
# 3           0   algorithms  c     United Kingdom   15.0      5
# 4           0   algorithms  c          Indonesia   15.0     20
#
#             problem_name difficulty skills  max_score
# 0  day-of-the-programmer       Easy  Basic         15
# 1  day-of-the-programmer       Easy  Basic         15
# 2  day-of-the-programmer       Easy  Basic         15
# 3  day-of-the-programmer       Easy  Basic         15
# 4  day-of-the-programmer       Easy  Basic         15

# %%
merged_df.tail
# Out:
# <bound method NDFrame.tail of        problem_id     problem_type     pl            country   score  count  \
# 0               0       algorithms      c              India   15.00   2100
# 1               0       algorithms      c            Germany   15.00      6
# 2               0       algorithms      c  Republic of Korea   15.00      8
# 3               0       algorithms      c     United Kingdom   15.00      5
# 4               0       algorithms      c          Indonesia   15.00     20
# ...           ...              ...    ...                ...     ...    ...
# 51297          56  data structures  cpp20               Null  150.00      1
# 51298          56  data structures  cpp20              India   81.80      1
# 51299          56  data structures  pypy3      United States  122.75      1
# 51300          56  data structures  pypy3              India   95.44      1
# 51301          56  data structures  pypy3              India   81.80      1
#
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51302 entries, 0 to 51301
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   problem_id    51302 non-null  int64
#  1   problem_type  51302 non-null  object
#  2   pl            51302 non-null  object
#  3   country       51301 non-null  object
#  4   score         51302 non-null  float64
#  5   count         51302 non-null  int64
#  6   problem_name  51302 non-null  object
#  7   difficulty    51302 non-null  object
#  8   skills        51302 non-null  object
#  9   max_score     51302 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 3.9+ MB

# %%
merged_df.describe(include='all')
# Out:
#           problem_id problem_type     pl        country         score  \
# count   51302.000000        51302  51302          51301  51302.000000
# unique           NaN            2     47            290           NaN
# top              NaN   algorithms    cpp  United States           NaN
# freq             NaN        41793   4896           3419           NaN
# mean       19.641866          NaN    NaN            NaN     25.249657
# std        17.963807          NaN    NaN            NaN     24.042509
# min         0.000000          NaN    NaN            NaN      0.000000
# 25%         4.000000          NaN    NaN            NaN     10.000000
# 50%        13.000000          NaN    NaN            NaN     20.000000
# 75%        37.000000          NaN    NaN            NaN     35.000000
# max        56.000000          NaN    NaN            NaN    150.000000
#
#                count     problem_name difficulty skills     max_score
# ...

# %%
merged_df
# Out:
#        problem_id     problem_type     pl            country   score  count  \
# 0               0       algorithms      c              India   15.00   2100
# 1               0       algorithms      c            Germany   15.00      6
# 2               0       algorithms      c  Republic of Korea   15.00      8
# 3               0       algorithms      c     United Kingdom   15.00      5
# 4               0       algorithms      c          Indonesia   15.00     20
# ...           ...              ...    ...                ...     ...    ...
# 51297          56  data structures  cpp20               Null  150.00      1
# 51298          56  data structures  cpp20              India   81.80      1
# 51299          56  data structures  pypy3      United States  122.75      1
# 51300          56  data structures  pypy3              India   95.44      1
# 51301          56  data structures  pypy3              India   81.80      1
#
# ...

# %%
merged_df.columns
# Out:
# Index(['problem_id', 'problem_type', 'pl', 'country', 'score', 'count',
#        'problem_name', 'difficulty', 'skills', 'max_score'],
#       dtype='object')

# %%
merged_df.dtypes
# Out:
# problem_id        int64
# problem_type     object
# pl               object
# country          object
# score           float64
# count             int64
# problem_name     object
# difficulty       object
# skills           object
# max_score         int64
# dtype: object

# %%
merged_df['problem_type']
# Out:
# 0             algorithms
# 1             algorithms
# 2             algorithms
# 3             algorithms
# 4             algorithms
#               ...
# 51297    data structures
# 51298    data structures
# 51299    data structures
# 51300    data structures
# 51301    data structures
# Name: problem_type, Length: 51302, dtype: object

# %%
merged_df['problem_type'].unique()
# Out:
# array(['algorithms', 'data structures'], dtype=object)

# %%
merged_df.nunique
# Out:
# <bound method DataFrame.nunique of        problem_id     problem_type     pl            country   score  count  \
# 0               0       algorithms      c              India   15.00   2100
# 1               0       algorithms      c            Germany   15.00      6
# 2               0       algorithms      c  Republic of Korea   15.00      8
# 3               0       algorithms      c     United Kingdom   15.00      5
# 4               0       algorithms      c          Indonesia   15.00     20
# ...           ...              ...    ...                ...     ...    ...
# 51297          56  data structures  cpp20               Null  150.00      1
# 51298          56  data structures  cpp20              India   81.80      1
# 51299          56  data structures  pypy3      United States  122.75      1
# 51300          56  data structures  pypy3              India   95.44      1
# 51301          56  data structures  pypy3              India   81.80      1
#
# ...

# %%
merged_df.head(5)
# Out:
#    problem_id problem_type pl            country  score  count  \
# 0           0   algorithms  c              India   15.0   2100
# 1           0   algorithms  c            Germany   15.0      6
# 2           0   algorithms  c  Republic of Korea   15.0      8
# 3           0   algorithms  c     United Kingdom   15.0      5
# 4           0   algorithms  c          Indonesia   15.0     20
#
#             problem_name difficulty skills  max_score
# 0  day-of-the-programmer       Easy  Basic         15
# 1  day-of-the-programmer       Easy  Basic         15
# 2  day-of-the-programmer       Easy  Basic         15
# 3  day-of-the-programmer       Easy  Basic         15
# 4  day-of-the-programmer       Easy  Basic         15

# %%
merged_df['problem_type'].value_counts()
# Out:
# problem_type
# algorithms         41793
# data structures     9509
# Name: count, dtype: int64

# %%
merged_df.value_counts()
# Out:
# problem_id  problem_type     pl      country             score   count  problem_name           difficulty  skills        max_score
# 0           algorithms       java    United States       9.840   4      day-of-the-programmer  Easy        Basic         15           2
#                              python  United States       10.500  1      day-of-the-programmer  Easy        Basic         15           2
#                              ada     Australia           15.000  1      day-of-the-programmer  Easy        Basic         15           1
# 26          algorithms       csharp  Serbia              35.000  1      construct-the-array    Medium      Intermediate  35           1
#                                      Indonesia           35.000  1      construct-the-array    Medium      Intermediate  35           1
#                                                                                                                                      ..
# ...

# %%
threshold = merged_df['score'].quantile(0.9)  # Top 10% threshold

# %%
top_performers = merged_df[merged_df['score'] >= threshold]

# %%
top_performers
# Out:
#        problem_id     problem_type     pl         country   score  count  \
# 25228          12       algorithms      c   United States   80.00      2
# 25229          12       algorithms      c           India   80.00     93
# 25230          12       algorithms      c  United Kingdom   80.00      1
# 25231          12       algorithms      c     Netherlands   80.00      1
# 25232          12       algorithms      c        Pakistan   80.00      1
# ...           ...              ...    ...             ...     ...    ...
# 51297          56  data structures  cpp20            Null  150.00      1
# 51298          56  data structures  cpp20           India   81.80      1
# 51299          56  data structures  pypy3   United States  122.75      1
# 51300          56  data structures  pypy3           India   95.44      1
# 51301          56  data structures  pypy3           India   81.80      1
#
#         problem_name difficulty skills  max_score
# ...

# %%
language_counts = top_performers['pl'].value_counts()
language_counts
# Out:
# pl
# cpp            940
# cpp14          695
# java8          600
# python3        567
# java           561
# csharp         414
# python         376
# c              266
# javascript     216
# pypy3          207
# go             201
# ruby           158
# java15         157
# scala          153
# kotlin         115
# haskell        111
# php             97
# swift           69
# pypy            61
# cpp20           59
# perl            49
# rust            37
# typescript      34
# clojure         24
# sbcl            22
# ocaml           16
# objectivec      14
# d               14
# fsharp          11
# pascal          11
# lua              9
# julia            9
# visualbasic      7
# groovy           6
# racket           5
# erlang           2
# r                1
# elixir           1
# ada              1
# Name: count, dtype: int64

# %%
language_counts.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Top Programming Languages Among Top Performers', fontsize=16)
plt.xlabel('Programming Language', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %%
avg_scores = merged_df.groupby(['problem_type', 'difficulty'])['score'].mean().reset_index()
avg_scores
# Out:
#       problem_type difficulty      score
# 0       algorithms   Advanced  58.505605
# 1       algorithms       Easy  16.356600
# 2       algorithms     Expert  40.505074
# 3       algorithms       Hard  41.641497
# 4       algorithms     Medium  30.688676
# 5  data structures   Advanced  60.183533
# 6  data structures       Easy   7.332669
# 7  data structures     Expert  61.388235
# 8  data structures       Hard  43.910615
# 9  data structures     Medium  38.163887

# %%
sns.barplot(data=avg_scores, x='problem_type', y='score', hue='difficulty', palette='viridis')
plt.title('Average Scores by Problem Type and Difficulty')
plt.ylabel('Average Score')
plt.xlabel('Problem Type')
plt.xticks(rotation=45)
plt.legend(title='Difficulty')

# %%
top_countries = merged_df.groupby('country')['score'].mean().sort_values(ascending=False).head(20)
top_countries
# Out:
# country
# Judgebot Land             100.000000
# Western Sahara             64.000000
# Brasil                     60.000000
# Indiana                    60.000000
# Saint Kitts and Nevis      56.666667
# Việt Nam                   51.666667
# North Korea                51.516000
# Åland Islands              50.000000
# 대한민국                       50.000000
# 美国                         50.000000
# Tanzania                   46.930667
# USA                        45.000000
# US                         42.500000
# INDIA                      41.666667
# Martinique                 40.000000
# China                      35.150649
# South Sudan                35.000000
# Saint Lucia                35.000000
# India                      34.446667
# Svalbard and Jan Mayen     33.428500
# Name: score, dtype: float64

# %%
from matplotlib import font_manager

fonts = sorted([f.name for f in font_manager.fontManager.ttflist])
print(fonts)
# Out:
# ['Agency FB', 'Agency FB', 'Algerian', 'Arial', 'Arial', 'Arial', 'Arial', 'Arial', 'Arial', 'Arial', 'Arial', 'Arial', 'Arial Rounded MT Bold', 'Arial Unicode MS', 'Bahnschrift', 'Baskerville Old Face', 'Bauhaus 93', 'Bell MT', 'Bell MT', 'Bell MT', 'Berlin Sans FB', 'Berlin Sans FB', 'Berlin Sans FB Demi', 'Bernard MT Condensed', 'Blackadder ITC', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Bodoni MT', 'Book Antiqua', 'Book Antiqua', 'Book Antiqua', 'Book Antiqua', 'Bookman Old Style', 'Bookman Old Style', 'Bookman Old Style', 'Bookman Old Style', 'Bookshelf Symbol 7', 'Bradley Hand ITC', 'Britannic Bold', 'Broadway', 'Brush Script MT', 'Calibri', 'Calibri', 'Calibri', 'Calibri', 'Calibri', 'Calibri', 'Californian FB', 'Californian FB', 'Californian FB', 'Calisto MT', 'Calisto MT', 'Calisto MT', 'Calisto MT', 'Cambria', 'Cambria', 'Cambria', 'Cambria', 'Candara', 'Candara', 'Candara', 'Candara', 
# ...

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Malgun Gothic'  
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='skyblue')
plt.xlabel('Average Score')
plt.ylabel('Country')
plt.title('Top 20 Countries by Average Score')
plt.gca().invert_yaxis()  # Reverse the order for readability
plt.tight_layout()
plt.show()
# Out:
# C:\Users\san\AppData\Local\Temp\ipykernel_8812\1803334113.py:9: UserWarning:
#
# Glyph 7879 (\N{LATIN SMALL LETTER E WITH CIRCUMFLEX AND DOT BELOW}) missing from current font.
#
# C:\Users\san\AppData\Local\Temp\ipykernel_8812\1803334113.py:9: UserWarning:
#
# Glyph 22269 (\N{CJK UNIFIED IDEOGRAPH-56FD}) missing from current font.
#
# C:\Users\san\anaconda PY\Anaconda Python\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 7879 (\N{LATIN SMALL LETTER E WITH CIRCUMFLEX AND DOT BELOW}) missing from current font.
#
# C:\Users\san\anaconda PY\Anaconda Python\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 22269 (\N{CJK UNIFIED IDEOGRAPH-56FD}) missing from current font.

# %%
import plotly.express as px

# Aggregate scores by country
country_scores = merged_df.groupby('country')['score'].mean().reset_index()

# Plot
fig = px.choropleth(
    country_scores,
    locations="country",
    locationmode="country names",
    color="score",
    title="Average Score by Country",
    color_continuous_scale=px.colors.sequential.Plasma,
)
fig.show()
# Out:
# <div>                            <div id="63170761-a068-4407-97e5-aae9c675b4fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63170761-a068-4407-97e5-aae9c675b4fd")) {                    Plotly.newPlot(                        "63170761-a068-4407-97e5-aae9c675b4fd",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"country=%{location}<br>score=%{z}<extra></extra>","locationmode":"country names","locations":["-","--","Afghanistan","Aland Islands","Albania","Algeria","Almanya","American Samoa","Andorra","Angola","Anguilla","Anonymous Proxy","Antarctica","Antigua and Barbuda","Argentina","Armenia","Aruba","Asia/Pacific Region","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangalore","Bangladesh","Barbados","Belaru
# ...

# %%
filtered_countries = merged_df.groupby('country').filter(lambda x: len(x) > 50)  
filtered_countries
# Out:
#        problem_id     problem_type     pl            country   score  count  \
# 0               0       algorithms      c              India   15.00   2100
# 1               0       algorithms      c            Germany   15.00      6
# 2               0       algorithms      c  Republic of Korea   15.00      8
# 3               0       algorithms      c     United Kingdom   15.00      5
# 4               0       algorithms      c          Indonesia   15.00     20
# ...           ...              ...    ...                ...     ...    ...
# 51297          56  data structures  cpp20               Null  150.00      1
# 51298          56  data structures  cpp20              India   81.80      1
# 51299          56  data structures  pypy3      United States  122.75      1
# 51300          56  data structures  pypy3              India   95.44      1
# 51301          56  data structures  pypy3              India   81.80      1
#
# ...

# %%
merged_df['country'].unique()
# Out:
# array(['India', 'Germany', 'Republic of Korea', 'United Kingdom',
#        'Indonesia', 'Bulgaria', 'United States', 'Brazil', 'Sri Lanka',
#        'Egypt', 'China', 'Canada', 'France', 'Romania', 'Bangladesh',
#        'Null', 'Israel', 'Dominican Republic', 'South Korea', 'Malaysia',
#        'Turkey', 'Vietnam', 'Australia', 'Mexico', 'Czech Republic',
#        'Spain', 'Taiwan', 'Finland', 'Poland', 'Singapore', 'Argentina',
#        'Venezuela', 'New Zealand', 'Greece', 'Russian Federation',
#        'Russia', 'Sweden', 'Latvia', 'Serbia', 'Colombia', 'Italy',
#        'Morocco', 'Ireland', 'Kazakhstan', 'Viet Nam', 'Portugal',
#        'Uzbekistan', 'Azerbaijan', 'Philippines', 'Belgium',
#        'Korea, Republic of', 'Ethiopia', 'Nepal', 'Hungary', 'Kenya',
#        'Nigeria', 'Bhutan', 'Republic of Moldova', 'Andorra',
#        'Switzerland', 'Mongolia', 'Slovakia', 'Pakistan',
#        'United Arab Emirates', 'Tunisia', 'Georgia', 'Japan',
# ...

# %%
merged_df['country'] = merged_df['country'].str.strip().str.lower()

# %%
merged_df['country'].head(10)
# Out:
# 0                india
# 1              germany
# 2    republic of korea
# 3       united kingdom
# 4            indonesia
# 5             bulgaria
# 6        united states
# 7               brazil
# 8            sri lanka
# 9                egypt
# Name: country, dtype: object

# %%
replacements = {
    'republic of korea': 'south korea',
    'korea, republic of': 'south korea',
    'viet nam': 'vietnam',
    'việt nam': 'vietnam',
    'usa': 'united states',
    'us': 'united states',
    'méxico': 'mexico',
    'russia': 'russian federation',
    'россия': 'russian federation',
    '대한민국': 'south korea',
    'india ': 'india',
    'u.s. virgin islands': 'united states virgin islands',
    'é': 'e',  
    '--': 'unknown',
    '-': 'unknown',
    'null': 'unknown',
    'nan': 'unknown'
}

# %%
merged_df['country'] = merged_df['country'].replace(replacements)

# %%
merged_df.country
# Out:
# 0                 india
# 1               germany
# 2           south korea
# 3        united kingdom
# 4             indonesia
#               ...
# 51297           unknown
# 51298             india
# 51299     united states
# 51300             india
# 51301             india
# Name: country, Length: 51302, dtype: object

# %%
valid_countries = [
    'india', 'germany', 'south korea', 'united kingdom', 'indonesia', 'bulgaria', 
    'united states', 'brazil', 'canada', 'france', 'japan', 'egypt', 'china', 'romania', 
    'bangladesh', 'israel', 'dominican republic', 'malaysia', 'turkey', 'vietnam', 
    'australia', 'mexico', 'czech republic', 'spain', 'taiwan', 'finland', 'poland', 
    'singapore', 'argentina', 'venezuela', 'new zealand', 'greece', 'russian federation', 
    'sweden', 'serbia', 'colombia', 'italy', 'morocco', 'ireland', 'kazakhstan', 'portugal', 
    'uzbekistan', 'azerbaijan', 'philippines', 'belgium', 'ethiopia', 'nepal', 'kenya', 
    'nigeria', 'bhutan', 'switzerland', 'mongolia', 'slovakia', 'united arab emirates', 
    'japan', 'chile', 'south africa', 'ukraine', 'peru', 'netherlands', 'denmark', 'croatia', 
    'jamaica', 'costa rica', 'el salvador', 'cuba', 'fiji', 'haiti', 'belize', 'senegal', 
    'swaziland', 'mali', 'angola', 'cape verde', 'tanzania', 'cyprus', 'gabon', 'botswana', 
    'burkina faso', 'grenada', 'maldives', 'guinea', 'niger', 'mozambique', 'liechtenstein', 
    'tokelau', 'lesotho', 'holy see', 'taiwan', 'samoa', 'east timor', 'iran', 'saint lucia', 
    'turks and caicos islands', 'djibouti', 'bosnia & herzegovina', 'poland', 'senegal', 
    'jamaica', 'sierraleone'
]

# %%
 merged_df = merged_df[merged_df['country'].isin(valid_countries)]

# %%
merged_df
# Out:
#        problem_id     problem_type     pl         country   score  count  \
# 0               0       algorithms      c           india   15.00   2100
# 1               0       algorithms      c         germany   15.00      6
# 2               0       algorithms      c     south korea   15.00      8
# 3               0       algorithms      c  united kingdom   15.00      5
# 4               0       algorithms      c       indonesia   15.00     20
# ...           ...              ...    ...             ...     ...    ...
# 51296          56  data structures  cpp20           india  150.00      7
# 51298          56  data structures  cpp20           india   81.80      1
# 51299          56  data structures  pypy3   united states  122.75      1
# 51300          56  data structures  pypy3           india   95.44      1
# 51301          56  data structures  pypy3           india   81.80      1
#
#                 problem_name difficulty skills  max_score
# ...

# %%
merged_df['country'].unique()
# Out:
# array(['india', 'germany', 'south korea', 'united kingdom', 'indonesia',
#        'bulgaria', 'united states', 'brazil', 'egypt', 'china', 'canada',
#        'france', 'romania', 'bangladesh', 'israel', 'dominican republic',
#        'malaysia', 'turkey', 'vietnam', 'australia', 'mexico',
#        'czech republic', 'spain', 'taiwan', 'finland', 'poland',
#        'singapore', 'argentina', 'venezuela', 'new zealand', 'greece',
#        'russian federation', 'sweden', 'serbia', 'colombia', 'italy',
#        'morocco', 'ireland', 'kazakhstan', 'portugal', 'uzbekistan',
#        'azerbaijan', 'philippines', 'belgium', 'ethiopia', 'nepal',
#        'kenya', 'nigeria', 'bhutan', 'switzerland', 'mongolia',
#        'slovakia', 'united arab emirates', 'japan', 'chile',
#        'south africa', 'ukraine', 'peru', 'cyprus', 'netherlands',
#        'denmark', 'croatia', 'iran', 'costa rica', 'el salvador', 'cuba',
#        'fiji', 'jamaica', 'angola', 'niger', 'cape verde', 'mozambique',
# ...

# %%
top_countries = merged_df.groupby('country')['score'].mean().sort_values(ascending=False).head(20)
top_countries
# Out:
# country
# tanzania                    46.930667
# china                       35.150649
# saint lucia                 35.000000
# djibouti                    33.333333
# mozambique                  31.469708
# burkina faso                30.357250
# russian federation          30.100376
# turks and caicos islands    30.000000
# czech republic              29.759470
# switzerland                 29.679129
# japan                       29.280481
# romania                     29.252231
# croatia                     29.191175
# singapore                   28.841444
# ukraine                     28.397440
# poland                      27.993473
# venezuela                   27.944434
# belgium                     27.586642
# bhutan                      27.350000
# germany                     27.149574
# Name: score, dtype: float64

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Malgun Gothic'  
plt.figure(figsize=(10, 6))
top_countries.plot(kind='barh', color='skyblue')
plt.xlabel('Average Score')
plt.ylabel('Country')
plt.title('Top 20 Countries by Average Score')
plt.gca().invert_yaxis()  # Reverse the order for readability
plt.tight_layout()
plt.show()

# %%
merged_df
# Out:
#        problem_id     problem_type     pl         country   score  count  \
# 0               0       algorithms      c           india   15.00   2100
# 1               0       algorithms      c         germany   15.00      6
# 2               0       algorithms      c     south korea   15.00      8
# 3               0       algorithms      c  united kingdom   15.00      5
# 4               0       algorithms      c       indonesia   15.00     20
# ...           ...              ...    ...             ...     ...    ...
# 51296          56  data structures  cpp20           india  150.00      7
# 51298          56  data structures  cpp20           india   81.80      1
# 51299          56  data structures  pypy3   united states  122.75      1
# 51300          56  data structures  pypy3           india   95.44      1
# 51301          56  data structures  pypy3           india   81.80      1
#
#                 problem_name difficulty skills  max_score
# ...

# %%
most_attempted = merged_df.groupby('problem_name')['count'].sum().sort_values(ascending=False).head(10)
most_attempted
# Out:
# problem_name
# time-conversion                     90766
# sock-merchant                       90114
# utopian-tree                        36350
# day-of-the-programmer               26772
# delete-a-node-from-a-linked-list    23864
# pangrams                            20878
# insertionsort1                      19413
# dynamic-array                       16518
# service-lane                        14491
# append-and-delete                   14160
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
most_attempted.plot(kind='bar', color='orange')
plt.title('Most Attempted Problems')
plt.ylabel('Attempt Count')
plt.xlabel('Problem Name')
plt.xticks(rotation=45)
plt.show()

# %%
merged_df['problem_name']
# Out:
# 0        day-of-the-programmer
# 1        day-of-the-programmer
# 2        day-of-the-programmer
# 3        day-of-the-programmer
# 4        day-of-the-programmer
#                  ...
# 51296                    helix
# 51298                    helix
# 51299                    helix
# 51300                    helix
# 51301                    helix
# Name: problem_name, Length: 41407, dtype: object

# %%
merged_df['problem_name'].unique()
# Out:
# array(['day-of-the-programmer', 'time-conversion', 'sock-merchant',
#        'utopian-tree', 'append-and-delete', 'taum-and-bday',
#        'service-lane', 'absolute-permutation', 'insertionsort1',
#        'pangrams', 'closest-numbers', 'game-of-thrones', 'count-strings',
#        'similar-strings', 'gridland-metro', 'maximizing-mission-points',
#        'playing-with-numbers', 'bfsshortreach', 'beautiful-path',
#        'johnland', 'bytelandian-tours', 'quadrant-queries', 'tsp-grid',
#        'marcs-cakewalk', 'greedy-florist', 'accessory-collection',
#        'construct-the-array', 'prime-xor', 'summing-pieces',
#        'taras-beautiful-permutations', 'play-game',
#        'counting-road-networks', 'a-super-hero',
#        'travel-around-the-world', 'zurikela', 'tree-pruning',
#        'count-ways-1', 'yet-another-minimax-problem',
#        'manipulative-numbers', 'the-power-sum', 'repeat-k-sums',
#        'tower-breakers-again-1', 'bob-and-ben', 'vertical-rooks',
# ...

# %%
merged_df.loc[:, 'problem_name'] = merged_df['problem_name'].str.strip()

# %%
merged_df
# Out:
#        problem_id     problem_type     pl         country   score  count  \
# 0               0       algorithms      c           india   15.00   2100
# 1               0       algorithms      c         germany   15.00      6
# 2               0       algorithms      c     south korea   15.00      8
# 3               0       algorithms      c  united kingdom   15.00      5
# 4               0       algorithms      c       indonesia   15.00     20
# ...           ...              ...    ...             ...     ...    ...
# 51296          56  data structures  cpp20           india  150.00      7
# 51298          56  data structures  cpp20           india   81.80      1
# 51299          56  data structures  pypy3   united states  122.75      1
# 51300          56  data structures  pypy3           india   95.44      1
# 51301          56  data structures  pypy3           india   81.80      1
#
#                 problem_name difficulty skills  max_score
# ...

# %%
lang_effectiveness = merged_df.groupby('pl')['score'].mean().sort_values(ascending=False).head(10)
lang_effectiveness
# Out:
# pl
# cpp14     37.618594
# pypy3     33.793117
# cpp20     30.640699
# cpp       30.064197
# java15    28.770577
# go        28.161638
# scala     28.069160
# java      27.981866
# java8     27.774214
# python    27.578516
# Name: score, dtype: float64

# %%
merged_df.rename(columns={'pl': 'prog_lang'}, inplace=True)
# Out:
# C:\Users\san\AppData\Local\Temp\ipykernel_8812\2697878865.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df
# Out:
#        problem_id     problem_type prog_lang         country   score  count  \
# 0               0       algorithms         c           india   15.00   2100
# 1               0       algorithms         c         germany   15.00      6
# 2               0       algorithms         c     south korea   15.00      8
# 3               0       algorithms         c  united kingdom   15.00      5
# 4               0       algorithms         c       indonesia   15.00     20
# ...           ...              ...       ...             ...     ...    ...
# 51296          56  data structures     cpp20           india  150.00      7
# 51298          56  data structures     cpp20           india   81.80      1
# 51299          56  data structures     pypy3   united states  122.75      1
# 51300          56  data structures     pypy3           india   95.44      1
# 51301          56  data structures     pypy3           india   81.80      1
#
# ...

# %%
merged_df['prog_lang'].unique()
# Out:
# array(['c', 'cpp', 'java', 'csharp', 'haskell', 'php', 'python', 'ruby',
#        'perl', 'bash', 'clojure', 'scala', 'javascript', 'typescript',
#        'lua', 'sbcl', 'erlang', 'go', 'd', 'ocaml', 'pascal', 'python3',
#        'groovy', 'objectivec', 'fsharp', 'visualbasic', 'lolcode', 'tcl',
#        'java8', 'java15', 'kotlin', 'r', 'racket', 'rust', 'fortran',
#        'swift', 'ada', 'cpp14', 'cpp20', 'elixir', 'pypy', 'pypy3',
#        'julia', 'smalltalk', 'octave', 'coffeescript', 'whitespace'],
#       dtype=object)

# %%
merged_df['prog_lang'].value_counts()
# Out:
# prog_lang
# cpp             3696
# python3         3504
# java8           3155
# java            2883
# csharp          2857
# javascript      2703
# python          2242
# cpp14           2168
# c               1825
# php             1414
# ruby            1273
# go              1208
# swift           1069
# scala           1068
# kotlin           983
# pypy3            947
# haskell          884
# java15           820
# typescript       712
# pypy             626
# perl             600
# objectivec       445
# clojure          435
# rust             385
# bash             321
# sbcl             277
# pascal           275
# cpp20            272
# fsharp           269
# groovy           253
# r                244
# lua              242
# visualbasic      202
# erlang           190
# ocaml            186
# julia            174
# d                149
# racket           128
# elixir           124
# tcl               61
# ada               38
# octave            35
# ...

# %%
lang_country = merged_df.groupby(['prog_lang', 'country'])['count'].describe().reset_index()
lang_country
# Out:
#        prog_lang       country  count  mean       std  min   25%  50%   75%  \
# 0            ada     australia    3.0   1.0  0.000000  1.0  1.00  1.0  1.00
# 1            ada    bangladesh    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# 2            ada        brazil    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# 3            ada      bulgaria    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# 4            ada        canada    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# ...          ...           ...    ...   ...       ...  ...   ...  ...   ...
# 2180  whitespace        canada    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# 2181  whitespace         india    2.0   1.5  0.707107  1.0  1.25  1.5  1.75
# 2182  whitespace       romania    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# 2183  whitespace  south africa    1.0   1.0       NaN  1.0  1.00  1.0  1.00
# 2184  whitespace   switzerland    1.0   1.0       NaN  1.0  1.00  1.0  1.00
#
#       max
# 0     1.0
# 1     1.0
# 2     1.0
# ...

# %%
import plotly.express as px

# Create an interactive bar plot
fig = px.bar(lang_country, x='prog_lang', y='count', color='country', title='Programming Language Counts by Country')
fig.update_layout(xaxis_tickangle=90)
fig.show()
# Out:
# <div>                            <div id="845def86-898f-49b6-aa16-6c565569a26c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("845def86-898f-49b6-aa16-6c565569a26c")) {                    Plotly.newPlot(                        "845def86-898f-49b6-aa16-6c565569a26c",                        [{"alignmentgroup":"True","hovertemplate":"country=australia<br>prog_lang=%{x}<br>count=%{y}<extra></extra>","legendgroup":"australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"australia","offsetgroup":"australia","orientation":"v","showlegend":true,"textposition":"auto","x":["ada","bash","c","clojure","coffeescript","cpp","cpp14","cpp20","csharp","d","elixir","erlang","fsharp","go","groovy","haskell","java","java15","java8","javascript","julia",
# ...

# %%
top_n_countries = lang_country.groupby('country')['count'].sum().nlargest(10).index
top_n_countries
# Out:
# Index(['united states', 'india', 'russian federation', 'united kingdom',
#        'vietnam', 'canada', 'germany', 'south korea', 'brazil', 'poland'],
#       dtype='object', name='country')

# %%
top_n_languages = lang_country.groupby('prog_lang')['count'].sum().nlargest(10).index
top_n_languages
# Out:
# Index(['cpp', 'python3', 'java8', 'java', 'csharp', 'javascript', 'python',
#        'cpp14', 'c', 'php'],
#       dtype='object', name='prog_lang')

# %%
lang_country_top_lang = lang_country[lang_country['prog_lang'].isin(top_n_languages)]
lang_country_top_lang
# Out:
#      prog_lang         country  count        mean         std  min  25%   50%  \
# 66           c          angola    3.0    1.000000    0.000000  1.0  1.0   1.0
# 67           c       argentina   19.0    2.578947    3.976539  1.0  1.0   1.0
# 68           c       australia   30.0    5.133333    7.290681  1.0  1.0   2.0
# 69           c      azerbaijan   12.0    4.833333    6.278873  1.0  1.0   2.0
# 70           c      bangladesh   55.0    6.163636   13.827996  1.0  1.0   1.0
# ...        ...             ...    ...         ...         ...  ...  ...   ...
# 1700   python3  united kingdom  121.0   23.396694   98.028608  1.0  1.0   2.0
# 1701   python3   united states  173.0  109.890173  530.485500  1.0  3.0  10.0
# 1702   python3      uzbekistan   19.0    3.578947    4.463628  1.0  1.0   1.0
# 1703   python3       venezuela   15.0    2.333333    2.160247  1.0  1.0   1.0
# 1704   python3         vietnam  113.0    9.867257   21.925403  1.0  1.0   2.0
#
#         75%     max
# ...

# %%
fig2 = px.bar(lang_country_top_lang, x='prog_lang', y='count', color='country', title='Programming Language Counts by Country')
fig2.update_layout(xaxis_tickangle=90)
fig2.show()
# Out:
# <div>                            <div id="f46a05af-47a6-4d73-8a50-21ea31f8fa8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f46a05af-47a6-4d73-8a50-21ea31f8fa8f")) {                    Plotly.newPlot(                        "f46a05af-47a6-4d73-8a50-21ea31f8fa8f",                        [{"alignmentgroup":"True","hovertemplate":"country=angola<br>prog_lang=%{x}<br>count=%{y}<extra></extra>","legendgroup":"angola","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"angola","offsetgroup":"angola","orientation":"v","showlegend":true,"textposition":"auto","x":["c","cpp","csharp","java8","javascript","php","python","python3"],"xaxis":"x","y":[3.0,1.0,1.0,2.0,2.0,1.0,1.0,4.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"c
# ...

# %%
lang_effectiveness2 = merged_df.groupby('prog_lang')['score'].mean().sort_values(ascending=False).head(10)
lang_effectiveness2
# Out:
# prog_lang
# cpp14     37.618594
# pypy3     33.793117
# cpp20     30.640699
# cpp       30.064197
# java15    28.770577
# go        28.161638
# scala     28.069160
# java      27.981866
# java8     27.774214
# python    27.578516
# Name: score, dtype: float64

# %%
plt.figure(figsize=(12, 6))
lang_effectiveness2.plot(kind='bar', color='green')
plt.title('Programming Language Effectiveness (Average Scores)')
plt.ylabel('Average Score')
plt.xlabel('Programming Language')
plt.xticks(rotation=45)
plt.show()

# %%
merged_df
# Out:
#        problem_id     problem_type prog_lang         country   score  count  \
# 0               0       algorithms         c           india   15.00   2100
# 1               0       algorithms         c         germany   15.00      6
# 2               0       algorithms         c     south korea   15.00      8
# 3               0       algorithms         c  united kingdom   15.00      5
# 4               0       algorithms         c       indonesia   15.00     20
# ...           ...              ...       ...             ...     ...    ...
# 51296          56  data structures     cpp20           india  150.00      7
# 51298          56  data structures     cpp20           india   81.80      1
# 51299          56  data structures     pypy3   united states  122.75      1
# 51300          56  data structures     pypy3           india   95.44      1
# 51301          56  data structures     pypy3           india   81.80      1
#
# ...

# %%
#Performing correlation analysis of the Dataframe
correlation_matrix = merged_df[['score', 'max_score', 'count']].corr()
correlation_matrix
# Out:
#               score  max_score     count
# score      1.000000   0.634693 -0.022202
# max_score  0.634693   1.000000 -0.047446
# count     -0.022202  -0.047446  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
skills_performance = merged_df.groupby('skills')['count'].mean().sort_values(ascending=False)

# %%
plt.figure(figsize=(12, 6))
skills_performance.plot(kind='bar', color='purple')
plt.title('Average Scores by Skill Level')
plt.ylabel('Average Score')
plt.xlabel('Skill Level')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Basic'),
#   Text(1, 0, 'Intermediate'),
#   Text(2, 0, 'Advanced'),
#   Text(3, 0, 'Null')])

# %%
skills_performance.reset_index()
# Out:
#          skills      count
# 0         Basic  17.993891
# 1  Intermediate   6.617017
# 2      Advanced   5.933841
# 3          Null   3.000899

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=skills_performance.index, y=skills_performance.values)
# Out:
# <Axes: xlabel='skills'>

# %%
# Histogram of scores
plt.figure(figsize=(10, 6))
sns.histplot(merged_df['score'], bins=20, kde=True, color='blue')
plt.title('Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
merged_df
# Out:
#        problem_id     problem_type prog_lang         country   score  count  \
# 0               0       algorithms         c           india   15.00   2100
# 1               0       algorithms         c         germany   15.00      6
# 2               0       algorithms         c     south korea   15.00      8
# 3               0       algorithms         c  united kingdom   15.00      5
# 4               0       algorithms         c       indonesia   15.00     20
# ...           ...              ...       ...             ...     ...    ...
# 51296          56  data structures     cpp20           india  150.00      7
# 51298          56  data structures     cpp20           india   81.80      1
# 51299          56  data structures     pypy3   united states  122.75      1
# 51300          56  data structures     pypy3           india   95.44      1
# 51301          56  data structures     pypy3           india   81.80      1
#
# ...

# %%
merged_df.isnull().sum()
# Out:
# problem_id      0
# problem_type    0
# prog_lang       0
# country         0
# score           0
# count           0
# problem_name    0
# difficulty      0
# skills          0
# max_score       0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# 395

# %%
merged_df.drop_duplicates(inplace=True)
# Out:
# C:\Users\san\AppData\Local\Temp\ipykernel_8812\1770524875.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df.head(5)
# Out:
#    problem_id problem_type prog_lang         country  score  count  \
# 0           0   algorithms         c           india   15.0   2100
# 1           0   algorithms         c         germany   15.0      6
# 2           0   algorithms         c     south korea   15.0      8
# 3           0   algorithms         c  united kingdom   15.0      5
# 4           0   algorithms         c       indonesia   15.0     20
#
#             problem_name difficulty skills  max_score
# 0  day-of-the-programmer       Easy  Basic         15
# 1  day-of-the-programmer       Easy  Basic         15
# 2  day-of-the-programmer       Easy  Basic         15
# 3  day-of-the-programmer       Easy  Basic         15
# 4  day-of-the-programmer       Easy  Basic         15

# %%
sns.boxplot(data=merged_df, x='count')
# Out:
# <Axes: xlabel='count'>

# %%
merged_df['difficulty'].unique()
# Out:
# array(['Easy', 'Medium', 'Hard', 'Advanced', 'Expert'], dtype=object)

# %%
Q1 = merged_df['count'].quantile(0.25)
Q3 = merged_df['count'].quantile(0.75)

# %%
print(Q1, Q3)
# Out:
# 1.0 3.0

# %%
# IQR = Q3-Q1
# IQR

# %%
# merged_df = merged_df[(merged_df['count'] >= (Q1 - 1.5 * IQR)) & (merged_df['count'] <= (Q3 + 1.5 * IQR))]

# %%
merged_df
# Out:
#        problem_id     problem_type prog_lang         country   score  count  \
# 0               0       algorithms         c           india   15.00   2100
# 1               0       algorithms         c         germany   15.00      6
# 2               0       algorithms         c     south korea   15.00      8
# 3               0       algorithms         c  united kingdom   15.00      5
# 4               0       algorithms         c       indonesia   15.00     20
# ...           ...              ...       ...             ...     ...    ...
# 51296          56  data structures     cpp20           india  150.00      7
# 51298          56  data structures     cpp20           india   81.80      1
# 51299          56  data structures     pypy3   united states  122.75      1
# 51300          56  data structures     pypy3           india   95.44      1
# 51301          56  data structures     pypy3           india   81.80      1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
merged_df['difficulty'] = label_encoder.fit_transform(merged_df['difficulty'])
# Out:
# C:\Users\san\AppData\Local\Temp\ipykernel_8812\1207577440.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df['difficulty'].unique()
# Out:
# array([1, 4, 3, 0, 2])

# %%
# merged_df = pd.get_dummies(merged_df, columns=['problem_type', 'prog_lang', 'country', 'skills'], drop_first=True)

# %%
country_freq = merged_df['country'].value_counts()
merged_df['country'] = merged_df['country'].map(country_freq)
# Out:
# C:\Users\san\AppData\Local\Temp\ipykernel_8812\3631835102.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df
# Out:
#        problem_id     problem_type prog_lang  country   score  count  \
# 0               0       algorithms         c     3205   15.00   2100
# 1               0       algorithms         c     1269   15.00      6
# 2               0       algorithms         c     1006   15.00      8
# 3               0       algorithms         c     1515   15.00      5
# 4               0       algorithms         c      897   15.00     20
# ...           ...              ...       ...      ...     ...    ...
# 51296          56  data structures     cpp20     3205  150.00      7
# 51298          56  data structures     cpp20     3205   81.80      1
# 51299          56  data structures     pypy3     3426  122.75      1
# 51300          56  data structures     pypy3     3205   95.44      1
# 51301          56  data structures     pypy3     3205   81.80      1
#
#                 problem_name  difficulty skills  max_score
# 0      day-of-the-programmer           1  Basic         15
# ...

# %%
merged_df['problem_type'].unique()
# Out:
# array(['algorithms', 'data structures'], dtype=object)

# %%
merged_df = pd.get_dummies(merged_df, columns=['problem_type'], drop_first=True, dtype=int)

# %%
merged_df
# Out:
#        problem_id prog_lang  country   score  count           problem_name  \
# 0               0         c     3205   15.00   2100  day-of-the-programmer
# 1               0         c     1269   15.00      6  day-of-the-programmer
# 2               0         c     1006   15.00      8  day-of-the-programmer
# 3               0         c     1515   15.00      5  day-of-the-programmer
# 4               0         c      897   15.00     20  day-of-the-programmer
# ...           ...       ...      ...     ...    ...                    ...
# 51296          56     cpp20     3205  150.00      7                  helix
# 51298          56     cpp20     3205   81.80      1                  helix
# 51299          56     pypy3     3426  122.75      1                  helix
# 51300          56     pypy3     3205   95.44      1                  helix
# 51301          56     pypy3     3205   81.80      1                  helix
#
#        difficulty skills  max_score  problem_type_data structures
# ...

# %%
merged_df['problem_name'].unique()
# Out:
# array(['day-of-the-programmer', 'time-conversion', 'sock-merchant',
#        'utopian-tree', 'append-and-delete', 'taum-and-bday',
#        'service-lane', 'absolute-permutation', 'insertionsort1',
#        'pangrams', 'closest-numbers', 'game-of-thrones', 'count-strings',
#        'similar-strings', 'gridland-metro', 'maximizing-mission-points',
#        'playing-with-numbers', 'bfsshortreach', 'beautiful-path',
#        'johnland', 'bytelandian-tours', 'quadrant-queries', 'tsp-grid',
#        'marcs-cakewalk', 'greedy-florist', 'accessory-collection',
#        'construct-the-array', 'prime-xor', 'summing-pieces',
#        'taras-beautiful-permutations', 'play-game',
#        'counting-road-networks', 'a-super-hero',
#        'travel-around-the-world', 'zurikela', 'tree-pruning',
#        'count-ways-1', 'yet-another-minimax-problem',
#        'manipulative-numbers', 'the-power-sum', 'repeat-k-sums',
#        'tower-breakers-again-1', 'bob-and-ben', 'vertical-rooks',
# ...

# %%
merged_df['skills'].unique()
# Out:
# array(['Basic', 'Intermediate', 'Null', 'Advanced'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
merged_df['skills'] = merged_df['skills'].fillna('Null')

skills_order = ['Basic', 'Intermediate', 'Advanced', 'Null']

encoder = OrdinalEncoder(categories=[skills_order])

merged_df['skills_encoded'] = encoder.fit_transform(merged_df[['skills']])

print(merged_df[['skills', 'skills_encoded']].head())
# Out:
#   skills  skills_encoded
# 0  Basic             0.0
# 1  Basic             0.0
# 2  Basic             0.0
# 3  Basic             0.0
# 4  Basic             0.0

# %%
merged_df.head(5)
# Out:
#    problem_id prog_lang  country  score  count           problem_name  \
# 0           0         c     3205   15.0   2100  day-of-the-programmer
# 1           0         c     1269   15.0      6  day-of-the-programmer
# 2           0         c     1006   15.0      8  day-of-the-programmer
# 3           0         c     1515   15.0      5  day-of-the-programmer
# 4           0         c      897   15.0     20  day-of-the-programmer
#
#    difficulty skills  max_score  problem_type_data structures  skills_encoded
# 0           1  Basic         15                             0             0.0
# 1           1  Basic         15                             0             0.0
# 2           1  Basic         15                             0             0.0
# 3           1  Basic         15                             0             0.0
# 4           1  Basic         15                             0             0.0

# %%
merged_df['skills_encoded'].unique()
# Out:
# array([0., 1., 3., 2.])

# %%
merged_df.drop('skills', axis=1, inplace=True)

# %%
merged_df
# Out:
#        problem_id prog_lang  country   score  count           problem_name  \
# 0               0         c     3205   15.00   2100  day-of-the-programmer
# 1               0         c     1269   15.00      6  day-of-the-programmer
# 2               0         c     1006   15.00      8  day-of-the-programmer
# 3               0         c     1515   15.00      5  day-of-the-programmer
# 4               0         c      897   15.00     20  day-of-the-programmer
# ...           ...       ...      ...     ...    ...                    ...
# 51296          56     cpp20     3205  150.00      7                  helix
# 51298          56     cpp20     3205   81.80      1                  helix
# 51299          56     pypy3     3426  122.75      1                  helix
# 51300          56     pypy3     3205   95.44      1                  helix
# 51301          56     pypy3     3205   81.80      1                  helix
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
problem_name_encoder = LabelEncoder()

# Apply Label Encoding to the problem_name column
merged_df['problem_name_encoded'] = problem_name_encoder.fit_transform(merged_df['problem_name'])

# Display the encoded values
print(merged_df[['problem_name', 'problem_name_encoded']].head())
# Out:
#             problem_name  problem_name_encoded
# 0  day-of-the-programmer                    14
# 1  day-of-the-programmer                    14
# 2  day-of-the-programmer                    14
# 3  day-of-the-programmer                    14
# 4  day-of-the-programmer                    14

# %%
merged_df
# Out:
#        problem_id prog_lang  country   score  count           problem_name  \
# 0               0         c     3205   15.00   2100  day-of-the-programmer
# 1               0         c     1269   15.00      6  day-of-the-programmer
# 2               0         c     1006   15.00      8  day-of-the-programmer
# 3               0         c     1515   15.00      5  day-of-the-programmer
# 4               0         c      897   15.00     20  day-of-the-programmer
# ...           ...       ...      ...     ...    ...                    ...
# 51296          56     cpp20     3205  150.00      7                  helix
# 51298          56     cpp20     3205   81.80      1                  helix
# 51299          56     pypy3     3426  122.75      1                  helix
# 51300          56     pypy3     3205   95.44      1                  helix
# 51301          56     pypy3     3205   81.80      1                  helix
#
# ...

# %%
merged_df['prog_lang'].unique()
# Out:
# array(['c', 'cpp', 'java', 'csharp', 'haskell', 'php', 'python', 'ruby',
#        'perl', 'bash', 'clojure', 'scala', 'javascript', 'typescript',
#        'lua', 'sbcl', 'erlang', 'go', 'd', 'ocaml', 'pascal', 'python3',
#        'groovy', 'objectivec', 'fsharp', 'visualbasic', 'lolcode', 'tcl',
#        'java8', 'java15', 'kotlin', 'r', 'racket', 'rust', 'fortran',
#        'swift', 'ada', 'cpp14', 'cpp20', 'elixir', 'pypy', 'pypy3',
#        'julia', 'smalltalk', 'octave', 'coffeescript', 'whitespace'],
#       dtype=object)

# %%
# Apply Label Encoding to the problem_name column
merged_df['prog_lang_encoded'] = label_encoder.fit_transform(merged_df['prog_lang'])

# Display the encoded values
print(merged_df[['prog_lang', 'prog_lang_encoded']].head())
# Out:
#   prog_lang  prog_lang_encoded
# 0         c                  2
# 1         c                  2
# 2         c                  2
# 3         c                  2
# 4         c                  2

# %%
merged_df
# Out:
#        problem_id prog_lang  country   score  count           problem_name  \
# 0               0         c     3205   15.00   2100  day-of-the-programmer
# 1               0         c     1269   15.00      6  day-of-the-programmer
# 2               0         c     1006   15.00      8  day-of-the-programmer
# 3               0         c     1515   15.00      5  day-of-the-programmer
# 4               0         c      897   15.00     20  day-of-the-programmer
# ...           ...       ...      ...     ...    ...                    ...
# 51296          56     cpp20     3205  150.00      7                  helix
# 51298          56     cpp20     3205   81.80      1                  helix
# 51299          56     pypy3     3426  122.75      1                  helix
# 51300          56     pypy3     3205   95.44      1                  helix
# 51301          56     pypy3     3205   81.80      1                  helix
#
# ...

# %%
merged_df = merged_df.drop(['prog_lang', 'problem_name'], axis=1)

# %%
merged_df
# Out:
#        problem_id  country   score  count  difficulty  max_score  \
# 0               0     3205   15.00   2100           1         15
# 1               0     1269   15.00      6           1         15
# 2               0     1006   15.00      8           1         15
# 3               0     1515   15.00      5           1         15
# 4               0      897   15.00     20           1         15
# ...           ...      ...     ...    ...         ...        ...
# 51296          56     3205  150.00      7           0        150
# 51298          56     3205   81.80      1           0        150
# 51299          56     3426  122.75      1           0        150
# 51300          56     3205   95.44      1           0        150
# 51301          56     3205   81.80      1           0        150
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 0                                 0             0.0                    14
# ...

# %%
merged_df.isnull().sum()
# Out:
# problem_id                      0
# country                         0
# score                           0
# count                           0
# difficulty                      0
# max_score                       0
# problem_type_data structures    0
# skills_encoded                  0
# problem_name_encoded            0
# prog_lang_encoded               0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# 98

# %%
merged_df.drop_duplicates(inplace=True)

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df
# Out:
#        problem_id  country   score  count  difficulty  max_score  \
# 0               0     3205   15.00   2100           1         15
# 1               0     1269   15.00      6           1         15
# 2               0     1006   15.00      8           1         15
# 3               0     1515   15.00      5           1         15
# 4               0      897   15.00     20           1         15
# ...           ...      ...     ...    ...         ...        ...
# 51296          56     3205  150.00      7           0        150
# 51298          56     3205   81.80      1           0        150
# 51299          56     3426  122.75      1           0        150
# 51300          56     3205   95.44      1           0        150
# 51301          56     3205   81.80      1           0        150
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 0                                 0             0.0                    14
# ...

# %%
merged_df['pass_fail'] = (merged_df['score'] > 50).astype(int)  # Assuming 50 is the threshold

# Target: pass_fail
y = merged_df['pass_fail']  # This is now a binary classification problem

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 51296    1
# 51298    1
# 51299    1
# 51300    1
# 51301    1
# Name: pass_fail, Length: 40914, dtype: int32

# %%
merged_df
# Out:
#        problem_id  country   score  count  difficulty  max_score  \
# 0               0     3205   15.00   2100           1         15
# 1               0     1269   15.00      6           1         15
# 2               0     1006   15.00      8           1         15
# 3               0     1515   15.00      5           1         15
# 4               0      897   15.00     20           1         15
# ...           ...      ...     ...    ...         ...        ...
# 51296          56     3205  150.00      7           0        150
# 51298          56     3205   81.80      1           0        150
# 51299          56     3426  122.75      1           0        150
# 51300          56     3205   95.44      1           0        150
# 51301          56     3205   81.80      1           0        150
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 0                                 0             0.0                    14
# ...

# %%
X = merged_df.drop(['score', 'pass_fail'], axis=1)

# %%
X
# Out:
#        problem_id  country  count  difficulty  max_score  \
# 0               0     3205   2100           1         15
# 1               0     1269      6           1         15
# 2               0     1006      8           1         15
# 3               0     1515      5           1         15
# 4               0      897     20           1         15
# ...           ...      ...    ...         ...        ...
# 51296          56     3205      7           0        150
# 51298          56     3205      1           0        150
# 51299          56     3426      1           0        150
# 51300          56     3205      1           0        150
# 51301          56     3205      1           0        150
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 0                                 0             0.0                    14
# 1                                 0             0.0                    14
# ...

# %%
corr_matrix = X.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
Q1 = X.quantile(0.25)
Q3 = X.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# problem_id                       34.0
# country                         879.0
# count                             2.0
# difficulty                        3.0
# max_score                        40.0
# problem_type_data structures      0.0
# skills_encoded                    2.0
# problem_name_encoded             26.0
# prog_lang_encoded                25.0
# dtype: float64

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
outliers = ((X < lower_bound) | (X > upper_bound))
outliers
# Out:
#        problem_id  country  count  difficulty  max_score  \
# 0           False     True   True       False      False
# 1           False    False  False       False      False
# 2           False    False   True       False      False
# 3           False    False  False       False      False
# 4           False    False   True       False      False
# ...           ...      ...    ...         ...        ...
# 51296       False     True   True       False       True
# 51298       False     True  False       False       True
# 51299       False     True  False       False       True
# 51300       False     True  False       False       True
# 51301       False     True  False       False       True
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 0                             False           False                 False
# 1                             False           False                 False
# ...

# %%
X_cleaned = X[~outliers.any(axis=1)]
X_cleaned
# Out:
#        problem_id  country  count  difficulty  max_score  \
# 1               0     1269      6           1         15
# 3               0     1515      5           1         15
# 5               0      500      3           1         15
# 10              0      903      5           1         15
# 16              0      572      2           1         15
# ...           ...      ...    ...         ...        ...
# 41786          44     1515      2           4         40
# 41789          44      880      2           4         40
# 41790          44     1046      1           4         40
# 41791          44      701      1           4         40
# 41792          44      684      1           4         40
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 1                                 0             0.0                    14
# 3                                 0             0.0                    14
# ...

# %%
X_cleaned = X[~outliers.any(axis=1)]
y_cleaned = y[~outliers.any(axis=1)]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_cleaned, y_cleaned, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#        problem_id  country  count  difficulty  max_score  \
# 36878          32     1076      1           3         80
# 19306           8      400      1           1         30
# 13460           4      897      1           1         20
# 11630           3      835      1           1         20
# 17672           6      490      1           1         20
# ...           ...      ...    ...         ...        ...
# 37538          34      880      1           3         80
# 10499           2     1076      2           1         10
# 1611            0      159      2           1         15
# 27941          16     1349      1           3         70
# 41131          42      335      4           4         50
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 36878                             0             3.0                     0
# 19306                             0             0.0                    23
# ...

# %%
X_test
# Out:
#        problem_id  country  count  difficulty  max_score  \
# 18402           7      599      5           4         40
# 14424           4      920      1           1         20
# 8691            2      186      1           1         10
# 6289            1      384      1           1         15
# 17821           7      315      1           4         40
# ...           ...      ...    ...         ...        ...
# 18239           7     1269      1           4         40
# 28763          17      570      1           4         55
# 36554          32      580      1           3         80
# 33030          24      285      2           4         35
# 30236          19     1046      1           4         60
#
#        problem_type_data structures  skills_encoded  problem_name_encoded  \
# 18402                             0             1.0                     1
# 14424                             0             0.0                     4
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print(X_test_scaled)
# Out:
# [[-0.51779357 -0.4598347   2.67608384 ...  0.092252   -1.63069246
#    1.04669362]
#  [-0.76093405  0.25985238 -0.60385962 ... -0.70834573 -1.4482163
#   -0.15230269]
#  [-0.9230277  -1.38578722 -0.60385962 ... -0.70834573  0.74149766
#    1.8460245 ]
#  ...
#  [ 1.50837712 -0.502433   -0.60385962 ...  1.69344745 -1.69151785
#   -1.51116518]
#  [ 0.8600025  -1.16382766  0.21612624 ... -0.70834573 -0.4750101
#   -0.07236961]
#  [ 0.45476836  0.54234637 -0.60385962 ...  1.69344745 -0.17088316
#   -1.03156666]]

# %%
print(X_train_scaled)
# Out:
# [[ 1.50837712  0.60960684 -0.60385962 ...  1.69344745 -1.69151785
#   -0.15230269]
#  [-0.43674674 -0.90599584 -0.60385962 ... -0.70834573 -0.29253393
#   -0.31216887]
#  [-0.76093405  0.20828601 -0.60385962 ... -0.70834573 -1.4482163
#   -1.59109827]
#  ...
#  [-1.08512136 -1.44632165  0.21612624 ... -0.70834573 -0.83996242
#    1.04669362]
#  [ 0.21162788  1.22167716 -0.60385962 ...  1.69344745  0.25489456
#   -0.07236961]
#  [ 2.31884539 -1.05172687  1.85609797 ...  1.69344745 -1.26574014
#   -1.19143283]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
model
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9404193481419971

# %%
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9404

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[4198  158]
#  [ 129  332]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4356
#            1       0.68      0.72      0.70       461
#
#     accuracy                           0.94      4817
#    macro avg       0.82      0.84      0.83      4817
# weighted avg       0.94      0.94      0.94      4817

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Create the model
model = RandomForestClassifier(random_state=42)

# Define the hyperparameters to tune
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'class_weight': ['balanced', None]
}

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Fit the model
grid_search.fit(X_train_scaled, y_train)

# Get the best parameters
print(f"Best Hyperparameters: {grid_search.best_params_}")

# Use the best model
best_model = grid_search.best_estimator_

# Evaluate on the test set
y_pred = best_model.predict(X_test_scaled)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best Hyperparameters: {'class_weight': None, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Accuracy: 0.9472700851152169

# %%
y_pred_test = grid_search.best_estimator_.predict(X_test_scaled)
print(f"Test Accuracy: {accuracy_score(y_test, y_pred_test)}")
print("Test Classification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Test Accuracy: 0.9472700851152169
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      4356
#            1       0.72      0.74      0.73       461
#
#     accuracy                           0.95      4817
#    macro avg       0.84      0.86      0.85      4817
# weighted avg       0.95      0.95      0.95      4817

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

smote = SMOTE(sampling_strategy='auto', random_state=42)
rf_model = RandomForestClassifier(random_state=42)
pipeline = ImbPipeline([('smote', smote), ('rf', rf_model)])

pipeline.fit(X_train_scaled, y_train)
y_pred = pipeline.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9379281710608263
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4356
#            1       0.65      0.75      0.70       461
#
#     accuracy                           0.94      4817
#    macro avg       0.81      0.86      0.83      4817
# weighted avg       0.94      0.94      0.94      4817

# %%
import sklearn
import imblearn

print(sklearn.__version__)
print(imblearn.__version__)
# Out:
# 1.5.2
# 0.12.4

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\san\anaconda PY\Anaconda Python\python.exe

# %%
# print(X_train_resampled.shape)
# print(y_train_resampled.shape)

# %%
print(pipeline)
# Out:
# Pipeline(steps=[('smote', SMOTE(random_state=42)),
#                 ('rf', RandomForestClassifier(random_state=42))])

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

estimators = [
    ('rf', RandomForestClassifier(random_state=42)),
    ('gb', GradientBoostingClassifier(random_state=42))
]
stack_model = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
stack_model.fit(X_train_scaled, y_train)
y_pred = stack_model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9449865061241437
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      4356
#            1       0.72      0.69      0.71       461
#
#     accuracy                           0.94      4817
#    macro avg       0.84      0.83      0.84      4817
# weighted avg       0.94      0.94      0.94      4817

# %%
from imblearn.ensemble import BalancedRandomForestClassifier

brf = BalancedRandomForestClassifier(random_state=42, n_estimators=100)
brf.fit(X_train_scaled, y_train)
y_pred = brf.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\san\AppData\Roaming\Python\Python311\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning:
#
# The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#
# C:\Users\san\AppData\Roaming\Python\Python311\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning:
#
# The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#
# C:\Users\san\AppData\Roaming\Python\Python311\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning:
#
# ...

# %%
rf_model = RandomForestClassifier(random_state=42, class_weight={0: 1, 1: 3})
rf_model.fit(X_train_scaled, y_train)
y_pred = rf_model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9412497405023874
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4356
#            1       0.68      0.72      0.70       461
#
#     accuracy                           0.94      4817
#    macro avg       0.83      0.84      0.83      4817
# weighted avg       0.94      0.94      0.94      4817

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X_train_scaled, y_train)

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_resampled, y_resampled)
y_pred = rf_model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9368901806103384
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      4356
#            1       0.64      0.76      0.70       461
#
#     accuracy                           0.94      4817
#    macro avg       0.81      0.86      0.83      4817
# weighted avg       0.94      0.94      0.94      4817

# %%
import joblib

# Assuming your model is in the variable `model`
joblib.dump(rf_model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
joblib.dump(country_freq, 'country_freq.pkl')

difficulty_encoder = LabelEncoder()
merged_df['difficulty'] = difficulty_encoder.fit_transform(merged_df['difficulty'])

joblib.dump(merged_df.columns, 'columns.pkl')

# Save OrdinalEncoder for 'skills'
joblib.dump(encoder, 'skills_encoder.pkl')

# Save LabelEncoder for 'problem_name'
joblib.dump(problem_name_encoder, 'problem_names_encoder.pkl')

# Save LabelEncoder for 'prog_lang'
joblib.dump(label_encoder, 'prog_lang_encoder.pkl')
# Out:
# ['prog_lang_encoder.pkl']

# %%
joblib.dump(difficulty_encoder, 'difficulty_encoder.pkl')
# Out:
# ['difficulty_encoder.pkl']
